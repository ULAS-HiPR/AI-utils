# %% [markdown]
# # Spectral Reconstruction
# To achieve spectral analysis of land from RGB imagery we need to create the spectral channels artificially using SOTA models.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Here is an example picture to perform augmentation on:

# %%
img = cv2.imread("../assets/green-field.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
